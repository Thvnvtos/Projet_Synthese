# %%
import numpy as np
import matplotlib.pyplot as plt

scores, dv, dt0, dt1, dh = [], [], [], [], []

with open("logs_0.03.txt", 'r') as f:
    line = f.readline()
    while line:
        x = line.split()
        scores.append(float(x[0]))
        dv.append(float(x[1]))
        dt0.append(float(x[2]))
        dt1.append(float(x[3]))
        dh.append(float(x[4]))
        line = f.readline()

# %%
dv = (dv - np.mean(dv))/np.std(dv)
dt0 = (dt0 - np.mean(dt0))/np.std(dt0)
dt1 = (dt1 - np.mean(dt1))/np.std(dt1)
dh = (dh - np.mean(dh))/np.std(dh)
# Out:
# /home/thanatos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# /home/thanatos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(10,10))
plt.plot(scores)
plt.title("Best solution score")
plt.figure(figsize=(10,10))
plt.plot(dv)
#plt.plot(dt0)
#plt.plot(dt1)
plt.plot(dh)
plt.legend(['dv','dt0','dt1','dh'])
plt.title("uncertainties")
# Out:
# Text(0.5, 1.0, 'uncertainties')
